# %% [markdown]
# ### 회귀분석

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

tips = sns.load_dataset('tips')

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
plt.plot(tips.total_bill, tips.tip, 'o')

# %%
plt.plot(tips.tip[0:10], tips.total_bill[0:10], 'o')

# %%
sns.set_style('darkgrid')
sns.lmplot(x='total_bill',y='tip',data=tips, size=7)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('darkgrid')
sns.lmplot(x='tip',y='total_bill',hue='smoker',data=tips, height=7)
plt.show()

# %%
fg = sns.load_dataset('flights')
fg.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
fg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
fg.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
fg.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
fg.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
fg.tail()
# Out:
#      year      month  passengers
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432

# %%
sns.set_style('darkgrid')
sns.lmplot(x='year',y='passengers',data=fg, height=7)
plt.show()

# %%
sns.set_style('darkgrid')
sns.lmplot(x='year',y='passengers',hue='month', data=fg, height=7)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='year', y='passengers', data=fg)
plt.title('passengers per year')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='month', y='passengers', data=fg)
plt.title('passengers per month')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='year', y='passengers', hue='month',data=fg)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='month', y='passengers', data=fg)
plt.show()

# %%
fgpivot=fg.pivot('month','year','passengers')
fgpivot
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# December    118   140   166   194   201   229   278   306   336   337   405
#
# year       1960
# month
# January     417
# February    391
# March       419
# April       461
# May         472
# June        535
# July        622
# August      606
# September   508
# October     461
# November    390
# December    432

# %%
sns.heatmap(fgpivot)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(fgpivot, annot=True, fmt='d')
plt.show()

# %%
iris=sns.load_dataset('iris')
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris_new = iris.loc[ : , 'sepal_length' : 'petal_width']
iris_new
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
iris_new.to_csv('iris_new.csv', index=False)
iris_new.to_excel('iris_new.xlsx', index=False)

# %% [markdown]
# ### 실습 2-2
# * tips 데이터 셋의 tip~size 데이터 선택해서 tips_new 변수 만들고,
# * 이에 대한 csv, xlsx 파일 생성

# %%
tips_new=tips.loc[:,'tip':'size']
tips_new.to_csv('tips_new.csv', index=False)
tips_new.to_excel('tips_new.xlsx', index=False)

# %% [markdown]
# ### 심화문제
# * 만든 csv/xlsx 파일을 불러와 다시 사용 가능한 상태로 만들기

# %%
dat=pd.read_csv('대구광역시립남부도서관 신착도서목록(2019년 2분기).csv',engine='python')
dat
# Out:
#         구분          등록번호           청구기호  \
# 0        1  EM0000379990     029.4-이68ㄷ
# 1        2  EM0000379991     005.1-마58ㅇ
# 2        3  EM0000379992    005.13-천73ㅋ
# 3        4  EM0000379993    005.13-화69ㄱ
# 4        5  EM0000379994  005.138-버838ㅍ
# ...    ...           ...            ...
# 2722  2723  EM0000384436    833.6-이215ㅅ
# 2723  2724  EM0000384437    833.6-나821ㅅ
# 2724  2725  EM0000384438     833.6-시78ㅇ
# 2725  2726  EM0000384439  911.059-황832ㄱ
# 2726  2727  EM0000384440  911.059-황832ㄱ
#
#                                                      서명  \
# 0                                     (내 삶을 바꾸는) 독서의 기적
# 1     (잠자는 코딩 브레인을 깨우는) 알고리즘 퍼즐69  : 수학적 사고로 구현하는 프로...
# 2                                    Core C Programming
# 3     Go를 활용한 머신 러닝  : Go 프로그래밍 언어를 사용해 회귀분석, 분류, 클러...
# 4     PHP & MySQL 닌자 비법서  : 견고한 웹 애플리케이션을 만들며 초보에서 고...
# ...                                                 ...
# 2722                                             성녀의 독배
# 2723                 시즈카 할머니에게 맡겨 줘  : 나카야마 시치리 단편 연작소설
# 2724                     (꿈꿀수록 쓰라린) 염원  : 시즈쿠이 슈스케 장편소설
# 2725                                         갑오왜란과 아관망명
# 2726      갑진왜란과 국민전쟁 : 대한제국의 패망과 대한민국의 부활:1904년부터 카이로까지
#
#                                  저작자    발행자   발행년     가격   자료실명
# 0                             이은희 지음   생각수레  2018  15000  종합자료실
# 1              마스이 토시카츠 지음  ; 윤인성 옮김    프리렉  2019  22000  종합자료실
# 2                             천정아 지음  연두에디션  2019  28000  종합자료실
# 3              다니엘 화이트낵 지음  ; 장세윤 옮김    에이콘  2019  30000  종합자료실
# 4     톰 버틀러, 케빈 양크 지음  ; 김재영, 정병열 옮김  한빛미디어  2019  35000  종합자료실
# ...                              ...    ...   ...    ...    ...
# 2722            이노우에 마기 지음  ; 이연승 옮김   스핑크스  2019  14000  종합자료실
# 2723           나카야마 시치리 지음  ; 강영혜 옮김   블루홀6  2019  14000  종합자료실
# 2724            시즈쿠이 슈스케 지음 ; 이연승 옮김   블루홀6  2019  13500  종합자료실
# 2725                          황태연 지음     청계  2017  48000  종합자료실
# 2726                          황태연 지음     청계  2017  48000  종합자료실
#
# [2727 rows x 9 columns]

# %%
dat['발행년'].unique()
# Out:
# array(['2018', '2019', '[2018]', '2017', '2016', '2010', '2012', '2011',
#        '2002', '2015', '2003', '2006', '1996', '2009', '2000', '2001',
#        '1997', '1998', '2014', '2004', '2007', '2005', '2013', '1995',
#        '1994', '1993', '2008', '1999'], dtype=object)

# %%
len(dat['서명'].unique())
# Out:
# 2638

# %%
len(dat['저작자'].unique())
# Out:
# 2513

# %%
len(dat['발행자'].unique())
# Out:
# 1265

# %%
dat.loc[dat['발행년']=='[2018]', :]
# Out:
#       구분          등록번호            청구기호            서명        저작자    발행자  \
# 210  211  EM0000380200  480.69411-테93ㄱ  가볼만한 수목원·식물원  테헤란씨씨 [편]  테헤란씨씨
#
#         발행년     가격   자료실명
# 210  [2018]  22000  종합자료실

# %%
dat.loc[dat['발행년']=='[2018]', :]=2018

# %%
dat.loc[dat['발행년']=='[2018]', :]
# Out:
# Empty DataFrame
# Columns: [구분, 등록번호, 청구기호, 서명, 저작자, 발행자, 발행년, 가격, 자료실명]
# Index: []

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2727 entries, 0 to 2726
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      2727 non-null   int64
#  1   등록번호    2727 non-null   object
#  2   청구기호    2727 non-null   object
#  3   서명      2727 non-null   object
#  4   저작자     2727 non-null   object
#  5   발행자     2727 non-null   object
#  6   발행년     2727 non-null   object
#  7   가격      2727 non-null   int64
#  8   자료실명    2727 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 191.9+ KB

# %%
plt.figure(figsize(15,8))
sns.barplot(x='발행년',y='가격',data=dat)
